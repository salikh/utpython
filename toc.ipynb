# %% [markdown]
# # 目次
#
# ▲で始まる項目は授業では扱いません。興味にしたがって学習してください。
#
# notebook全体に▲が付いているものもありますので注意してください。
#
# ## 第0回
#
# ### [Pythonの準備](0_guidance/guidance1.ipynb)
#
# * Python
# * Anaconda / Jupyter Notebook
# * Python環境のセットアップ
# * Python環境のセットアップ（Windows向け）
# * Python環境のセットアップ（Mac向け）
# * Python環境のセットアップ (Google Colaboratory)
#
# ## 第1回
#
# ### [1-0. Jupyter Notebook の使い方](1/1-0.ipynb)
#
# * セル
# * コマンドモード
# * 編集モード
# * （注意）Shift-Enterに反応がなくなったとき
#
# ### [1-1. 数値演算](1/1-1.ipynb)
#
# * 簡単な算術計算
# * コメント
# * 整数と実数
# * 演算子の優先順位と括弧
# * 算術演算子のまとめ
# * 空白
# * エラー
# * 数学関数（モジュールのインポート）
#
# ### [1-2. 変数と関数の基礎](1/1-2.ipynb)
#
# * 変数
# * 関数の定義と返値
# * ローカル変数
# * `print`
# * `print` と `return`
# * コメントと空行
# * 関数の参照の書き方
# * ▲グローバル変数
#
# ### [1-3. 論理・比較演算と条件分岐の基礎](1/1-3.ipynb)
#
# * if文による条件分岐
# * 様々な条件
# * 真理値を返す関数
# * オブジェクト
# * `None`
# * ▲条件として使われる他の値
# * ▲再帰
#
# ### [1-4. デバッグ](1/1-4.ipynb)
#
# * **文法エラー**：Syntax Errors
# * **実行エラー**：Runtime Errors
# * **論理エラー**：Logical Errors
# * `print` によるデバッグ
# * ▲assert文によるデバッグ
#
# ## 第2回
#
# ### [2-1. 文字列 (string)](2/2-1.ipynb)
#
# * 文字列とインデックス
# * 文字列とスライス
# * 空文字列
# * 文字列の検索
# * ▲エスケープシーケンス
# * 文字列の連結
# * 文字列とメソッド
# * **文字列の比較演算**
# * 初心者によくある誤解 --- **変数**と**文字列**の混乱
#
# ### [2-2. リスト (list)](2/2-2.ipynb)
#
# * リストとインデックス
# * **多重リスト**
# * リストに対する関数・演算子・メソッド
# * 破壊的（インプレース）な操作と非破壊的な生成
# * リストを操作するメソッドなど
# * タプル (tuple)
# * 多重代入
# * リストやタプルの比較演算
# * for文による繰り返しとリスト・タプル
# * for文による繰り返しと文字列
# * ▲for文によるリスト初期化の短縮記法
# * ▲オブジェクトの等価性と同一性
#
# ### [2-3. **条件分岐**](2/2-3.ipynb)
#
# * インデントによる構文
# * **`if`** ... **`else`** による条件分岐
# * **`if`** ... **`elif`** ... **`else`** による条件分岐
# * ▲複数行にまたがる条件式
# * **`if`** ... **`elif`** ... **`else`** における条件の評価
# * `or` もしくは `and` で結合された条件の評価
# * ▲**3項演算子**（条件式）
#
# ## 第3回
#
# ### [3-1. 辞書 (dictionary)](3/3-1.ipynb)
#
# * 辞書のメソッド
# * 辞書とリスト
#
# ### [3-2. **繰り返し**](3/3-2.ipynb)
#
# * for文による繰り返し
# * for文による繰り返しと辞書
# * `range`
# * `range` とリスト
# * for文の**入れ子**
# * for文の**計算量**
# * **`enumerate`**
# * **`in`**
# * while文による繰り返し
# * 制御構造とreturn文
# * **break文**
# * **continue文**
# * ▲for文とwhile文における **`else`**
# * **pass文**
#
# ### [3-3. 関数](3/3-3.ipynb)
#
# * 関数の定義
# * 引数
# * 返値
# * 複数の引数
# * 変数とスコープ
# * ▲キーワード引数
# * ▲引数の初期値
# * ▲可変長引数
# * ▲辞書型の可変長引数
# * ▲引数の順番
# * ▲変数としての関数
#
# ## 第4回
#
# ### [4-1. ファイル入出力の基本](4/4-1.ipynb)
#
# * ファイルのオープン
# * ファイルのクローズ
# * ファイル全体の読み込み
# * 行の読み込み
# * 編集中のファイルの動作
# * ファイルに対するwith文
# * ファイルへの書き込み
# * ファイルの読み書きにおける文字コード指定
# * 改行文字の削除
#
# ### [4-2. イテレータ](4/4-2.ipynb)
#
# * `next`
# * for文による繰り返しとファイルオブジェクト
# * `iter`
# * イテラブル
# * イテレータを返す `enumerate`
#
# ### [4-3. コンピュータにおけるファイルやディレクトリの配置](4/4-3.ipynb)
#
# * カレントディレクトリ
# * 相対パスと絶対パス
# * 木構造によるデータ表現
#
# ## 第5回
#
# ### [5-1. モジュールの使い方](5/5-1.ipynb)
#
# * モジュールのインポート
# * `from`
# * `as`
#
# ### [5-2. モジュールの作り方](5/5-2.ipynb)
#
# * モジュールファイル
# * Jupyter Notebook でモジュールを扱う
# * 自作モジュールの使い方
#
# ### [5-3. NumPyライブラリ](5/5-3.ipynb)
#
# * 配列の構築
# * 配列要素を生成する構築関数
# * 配列要素の操作
# * 要素毎の演算
# * よく使われる配列操作
# * 配列の保存と復元
# * ▲**真理値配列によるインデックスアクセス**
# * ▲線形代数の演算
#
# ## 第6回
#
# ### [6-1. **内包表記**](6/6-1.ipynb)
#
# * リスト内包表記
# * 内包表記の入れ子
# * ▲**条件付き内包表記**
# * ▲**セット内包表記**
# * ▲**辞書内包表記**
# * ▲**ジェネレータ式**
#
# ### [6-2. 高階関数](6/6-2.ipynb)
#
# * `max`
# * `sorted`
# * ラムダ式
# * リストからイテラブルへ
# * `map`
# * `filter`
#
# ### [6-3. クラス](6/6-3.ipynb)
#
# * クラス定義
# * 初期化と属性
# * 継承
# * 特殊メソッド
# * ▲with文への対応
#
# ## 第7回
#
# ### [7-1. pandasライブラリ](7/7-1.ipynb)
#
# * シリーズとデータフレーム
# * シリーズ (`Series`) の作成
# * データフレーム (`DataFrame`) の作成
# * CSVファイルからのデータフレームの作成
# * データの参照
# * データの条件取り出し
# * 列の追加と削除
# * 行の追加と削除
# * データの並び替え
# * データの統計量
# * ▲データの連結
# * ▲データの結合
# * ▲データのグループ化
# * ▲欠損値、時系列データの処理
#
# ### [7-2. scikit-learnライブラリ](7/7-2.ipynb)
#
# * 機械学習について
# * 教師あり学習
# * 教師なし学習
# * データ
# * モデル学習の基礎
# * 教師あり学習・分類の例
# * 教師あり学習・回帰の例
# * 教師なし学習・クラスタリングの例
# * 教師なし学習・次元削減の例
#
# ## 付録
# ### 第2回 [▲セット (set)](appendix/2-set.ipynb)
#
# * セットの組み込み関数
# * **集合演算**
# * **比較演算**
# * セットのメソッド
#
# ### 第3回 [▲再帰](appendix/3-recursion.ipynb)
#
# * 再帰関数の例：接頭辞リストと接尾辞リスト
# * 再帰関数の例：べき乗の計算
# * 再帰関数の例：マージソート
#
# ### 第3回 [▲簡単なデータの可視化](appendix/3-visualization.ipynb)
#
# * **`matplotlib`**
# * 折れ線グラフ
# * 散布図
# * 棒グラフ
#
# ### 第4回 [▲CSVファイルの入出力](appendix/4-csv.ipynb)
#
# * CSV形式とは
# * CSVファイルの読み込み
# * CSVファイルに対するfor文
# * CSVファイルに対するwith文
# * CSVファイルの書き込み
#
# ### 第5回 [▲Bokehライブラリ](appendix/5-bokeh.ipynb)
#
# * 線グラフ
# * 散布図
# * 棒グラフ
# * ヒストグラム
# * ヒートマップ
# * グラフのファイル出力
#
# ### 第5回 [▲Pythonスクリプトとコマンドライン実行](appendix/5-command.ipynb)
#
# * コマンドライン実行の具体例
# * コマンドライン引数
# * モジュールのコマンドライン実行
# * ソースファイル先頭部分にある宣言
#
# ### 第5回 [▲Matplotlibライブラリ](appendix/5-matplotlib.ipynb)
#
# * 線グラフ
# * 散布図
# * 棒グラフ
# * ヒストグラム
# * ヒートマップ
# * グラフの画像ファイル出力
#
# ### 第5回 [▲正規表現](appendix/5-re.ipynb)
#
# * 正規表現の基本
# * 正規表現の応用1
# * 正規表現に関する基本的な関数
# * 正規表現の応用2
# * メタ文字
# * 正規表現のエスケープシーケンス
# * 正規表現に関する関数とメソッド
#
#
# ## [索引](index.ipynb)
